# %% [markdown]
# # E043 — pipeline visuelle finale

# %%
from pathlib import Path
import json
from IPython.display import display, Image, Markdown
R=Path('/data/e043-scanner-cell-frontier-v1')
v=json.loads((R/'verdict.json').read_text(encoding='utf-8'))
display(v)
display(Image(filename=str(R/'pipeline/full-pipeline-contact-sheet.png')))

# %% [markdown]
# La chaîne E043 reste appariée au prompt E041. `99-FINAL-QR.png` est le meilleur checkpoint **visuellement sûr** selon QR-Verify réel. Aucun résultat n'autorise encore la généralisation.

# %%
display(Markdown(f"**Winner:** `{v['winner_variant']}` — **SSR {v['winner_ssr_exact_presets']}/37** — original={v['winner_original_exact']} — safe={v['winner_visual_guard_pass']}"))
display(Image(filename=str(R/'pipeline/99-FINAL-QR.png'), width=600))
