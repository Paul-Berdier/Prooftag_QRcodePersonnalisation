# %% [markdown]
# # E041 — Pipeline finale visuelle
#
# QR → condition → Stage 1 → Stage 2 → gamma/scan-aware → renforcement fonctionnel → final.

# %%
from pathlib import Path
import json, os
from IPython.display import Image as DisplayImage, Markdown, display
RESULTS_DIR=Path(os.environ.get('E041_RESULTS_DIR','/data/e041-gamma-functional-pattern-frontier-v1'))
v=json.loads((RESULTS_DIR/'verdict.json').read_text(encoding='utf-8'))

# %% [markdown]
# ## 1. QR référence

# %%
display(DisplayImage(filename=str(RESULTS_DIR/'pipeline/01-qr-reference.png'),width=650))

# %% [markdown]
# ## 2. Condition ControlNet

# %%
display(DisplayImage(filename=str(RESULTS_DIR/'pipeline/02-control-condition.png'),width=650))

# %% [markdown]
# ## 3. Stage 1 — nouveau prompt

# %%
display(DisplayImage(filename=str(RESULTS_DIR/'pipeline/03-stage1.png'),width=800))

# %% [markdown]
# ## 4. Stage 2 SRPG

# %%
display(DisplayImage(filename=str(RESULTS_DIR/'pipeline/04-stage2.png'),width=800))

# %% [markdown]
# ## 5. Stage 2 scan-ready

# %%
display(DisplayImage(filename=str(RESULTS_DIR/'pipeline/05-stage2-scan-ready.png'),width=800))

# %% [markdown]
# ## 6. Gamma sélectionné + checkpoint

# %%
display(Markdown(f"**gamma={v['selected_gamma']} / i{v['selected_iteration']}**"))

# %% [markdown]
# ## 7. Renforcement motifs fonctionnels

# %%
display(Markdown(f"**functional_pattern_tone_factor={v['selected_functional_tone_factor']}**"))

# %% [markdown]
# ## 8. QR FINAL

# %%
display(DisplayImage(filename=str(RESULTS_DIR/'pipeline/99-FINAL-QR.png'),width=850))
display(v)

# %% [markdown]
# ## 9. Vue complète

# %%
display(DisplayImage(filename=str(RESULTS_DIR/'pipeline/full-pipeline-contact-sheet.png'),width=1500))

# %% [markdown]
# ## 10. Advisor

# %%
advisor=json.loads((RESULTS_DIR/'advisor-preview.json').read_text(encoding='utf-8')); display(advisor)
